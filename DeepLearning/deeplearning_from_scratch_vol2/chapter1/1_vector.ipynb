# %%
import numpy as np

# %%
x = np.array([1, 2, 3])
x.__class__
# Out:
# numpy.ndarray

# %%
x.shape
# Out:
# (3,)

# %%
x.ndim
# Out:
# 1

# %%
W = np.array([[1, 2, 3], [4, 5, 6]])

# %%
W.shape
# Out:
# (2, 3)

# %%
W.ndim
# Out:
# 2

# %%
W = np.array([[1, 2, 3], [4, 5, 6]])
X = np.array([[0, 1, 2], [3, 4, 5]])

# %%
W + X
# Out:
# array([[ 1,  3,  5],
#        [ 7,  9, 11]])

# %%
W * X
# Out:
# array([[ 0,  2,  6],
#        [12, 20, 30]])
