# %%
import numpy as np

# %%
t = np.random.binomial(5, 0.3, size=1000)

# %%
s = np.bincount(t)

# %%
s
# Out:
# array([180, 368, 294, 128,  24,   6])

# %%
s/s.sum()
# Out:
# array([0.18 , 0.368, 0.294, 0.128, 0.024, 0.006])
