# %%
import numpy as np

# %%
t = np.random.poisson(5, size=1000)

# %%
s = np.bincount(t)
s
# Out:
# array([  4,  34,  86, 149, 178, 185, 130, 100,  69,  25,  21,  12,   3,
#          2,   1,   1])

# %%
t.max()
# Out:
# np.int64(15)

# %%
s = s/s.sum()
s
# Out:
# array([0.004, 0.034, 0.086, 0.149, 0.178, 0.185, 0.13 , 0.1  , 0.069,
#        0.025, 0.021, 0.012, 0.003, 0.002, 0.001, 0.001])
