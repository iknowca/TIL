# %%
import numpy as np

# %%
t = np.random.binomial(1, 0.5, size=1000)
np.bincount(t)
# Out:
# array([508, 492])

# %%
t = np.random.binomial(1, 0.3, size=1000)
np.bincount(t)
# Out:
# array([692, 308])
