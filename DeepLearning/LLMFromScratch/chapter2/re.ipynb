# %%
import re

from chapter2.simple_tokenizer_v1 import SimpleTokenizerV1

text = "Hello, world. This, is a test."
result = re.split(r'(\s)', text)
print(result)
# Out:
# ['Hello,', ' ', 'world.', ' ', 'This,', ' ', 'is', ' ', 'a', ' ', 'test.']

# %%
result = re.split(r'([,.]|\s)', text)
print(result)
# Out:
# ['Hello', ',', '', ' ', 'world', '.', '', ' ', 'This', ',', '', ' ', 'is', ' ', 'a', ' ', 'test', '.', '']

# %%
result = [item for item in result if item.strip()]
print(result)
# Out:
# ['Hello', ',', 'world', '.', 'This', ',', 'is', 'a', 'test', '.']

# %%
text = "Hello, world. Is this-- a test?"
result = re.split(r'([,.:;?_!"()\']|\s)', text)
result = [item for item in result if item.strip()]
print(result)
# Out:
# ['Hello', ',', 'world', '.', 'Is', 'this--', 'a', 'test', '?']

# %%
raw_text = ""
with open('the_verdict.txt', "r", encoding="utf-8") as f:
    raw_text = f.read()

preprocessed = re.split(r'([,.:;?_!"()\']|\s)', raw_text)
preprocessed = [item for item in preprocessed if item.strip()]
print(preprocessed[:30])
# Out:
# ['I', 'HAD', 'always', 'thought', 'Jack', 'Gisburn', 'rather', 'a', 'cheap', 'genius--though', 'a', 'good', 'fellow', 'enough--so', 'it', 'was', 'no', 'great', 'surprise', 'to', 'me', 'to', 'hear', 'that', ',', 'in', 'the', 'height', 'of', 'his']

# %%
vocab = {token: integer for integer, token in enumerate(preprocessed)}
for i, item in enumerate(vocab.items()):
    print(item)
    if i > 50:
        break
# Out:
# ('I', 4473)
# ('HAD', 1)
# ('always', 3667)
# ('thought', 4406)
# ('Jack', 2333)
# ('Gisburn', 2809)
# ('rather', 4225)
# ('a', 4462)
# ('cheap', 8)
# ('genius--though', 9)
# ('good', 300)
# ('fellow', 12)
# ('enough--so', 13)
# ('it', 4483)
# ('was', 4303)
# ('no', 4498)
# ('great', 4086)
# ('surprise', 2631)
# ('to', 4446)
# ('me', 4485)
# ('hear', 4137)
# ('that', 4472)
# (',', 4491)
# ('in', 4413)
# ('the', 4467)
# ('height', 69)
# ('of', 4502)
# ('his', 4456)
# ('glory', 3303)
# ('he', 4426)
# ('had', 3903)
# ('dropped', 2838)
# ('painting', 3306)
# ('married', 509)
# ('rich', 772)
# ('widow', 41)
# ('and', 4492)
# ('established', 44)
# ('himself', 4388)
# ('villa', 48)
# ('on', 4458)
# ('Riviera', 588)
# ('.', 4504)
# ('(', 753)
# ('Though', 54)
# ('would', 4389)
# ('have', 4390)
# ('been', 4400)
# ('Rome', 62)
# ('or', 3670)
# ('Florence', 64)
# (')', 758)

# %%
from simple_tokenizer_v1 import SimpleTokenizerV1
tokenizer = SimpleTokenizerV1(vocab)
text = """
"It's the last he painted, you know,"
Mrs. Gisburn said with pardonable pride.
"""

ids = tokenizer.encode(text)
print(ids)
# Out:
# [4505, 4234, 4496, 4497, 4467, 3717, 4426, 4329, 4491, 4151, 4057, 4491, 4505, 4299, 4504, 2809, 4210, 4461, 1894, 2103, 4504]

# %%
print(tokenizer.decode(ids))
# Out:
# " It' s the last he painted, you know," Mrs. Gisburn said with pardonable pride.

# %%
text = "Hello, do you like tea?"
print(tokenizer.encode(text))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 2
#       1 text = "Hello, do you like tea?"
# ----> 2 print(tokenizer.encode(text))
#
# File C:\wonki\study\TIL\DeepLearning\LLMFromScratch\chapter2\simple_tokenizer_v1.py:12, in SimpleTokenizerV1.encode(self, text)
#      10 preprocessed = re.split(r'([,.:;?_!"()\']|\s)', text)
#      11 preprocessed = [item.strip() for item in preprocessed if item.strip()]
# ---> 12 ids = [self.str_to_int[s] for s in preprocessed]
#      13 return ids
#
# KeyError: 'Hello'
